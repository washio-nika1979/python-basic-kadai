# %%
array = ['水','金','地','火','木','土','天','海','冥']
for i in range(0,9):
  print(str(i+1) + array[i])
j = 0
while 0 <= j <=8:
  print(str(j+10) + array[j])
  j = j+1
# Out:
# 1水
# 2金
# 3地
# 4火
# 5木
# 6土
# 7天
# 8海
# 9冥
# 10水
# 11金
# 12地
# 13火
# 14木
# 15土
# 16天
# 17海
# 18冥

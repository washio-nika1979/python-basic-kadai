# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(self.name)
    print(self.age)

student1 = Human('washio',46)

student1.printinfo()
# Out:
# washio
# 46
